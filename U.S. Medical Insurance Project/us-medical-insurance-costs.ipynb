# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# # Looking over the info
#
# ## What info i have? (and what order this info has?)
# Patients with their age , sex , bmi(body mass index),  how many children they have, if they are smokers, their region,  and their insurances total costs or charges.
#
# ## How is this info represented?
# A csv file that separates every separating each info of the patient by commas, and a patient by line. Each data is represented this way:
#
# age = an integer number.
#
# sex = word male or female
#
# bmi = a float number
#
# children = a number representing the amount of children they have
#
# smoker = "yes" for smokers and "no" for non-smokers
#
# region = can be southeast, southwest, northeast or northwest
#
# charges = their insurances cost in a float number
#
# ## What do i want to find out about this data? Or what i wanna do with it?
# Average insurance cost by region? Does the region may affect the insurance cost for some reason?
#
# Does the bmi varies by region? or somehow it is related to their smoker condition? it is even related to the age or the amount of childs they have?
#
# Who smokes more by sex and age?
#
# Organize the data by the bmi , knowing somone is healthier by some conditions. Just as well as with smokers
# Organize the data in different ways(can be creaive with this, doing functions for different infos)

# %% [markdown]
# # Scoping
# ## Main Goals
# - Organize the data the best way possible: by patient, split by sex, split by smoker, split by average bmi, split by region, etc.
# - Studying the data, answers the questions made before
# - Maybe making a program to interact with the user?

# %% [markdown]
# First it is important to get the data from the file given __insurance.csv__
#
# For this the *csv* module is needed to get the data from the file given. And Throught this module we can get all the information into a list of dictionaries that contain ech data of the patients.

# %%
import csv
patients_list = []
with open("insurance.csv") as insurances:
    insurances_reader = csv.DictReader(insurances)
    for insurance in insurances_reader:
        patients_list.append(insurance)
        #print(insurance)

print(len(patients_list))
# Out:
# 1338

# %% [markdown]
# Now the data is stored in a list of ditionaries, There are multiple ways to work with this data. One way is creating a class called __Patient__ storing each patients data thre an work with them as we want creating different methods.

# %%
class Patient:
    patient_id = 0
    def __init__(self, patient):
        # checking if the info to initiate the class is correct
        if type(patient) != dict:
            print("Error: patient given isnt a dictionary type")
            return None
        elif len(patient) != 7:
            print("Patient info incomplete or more info than expected")
            return None
        # initiating the class
        self.age = patient["age"]
        self.sex = patient["sex"]
        self.bmi = patient["bmi"]
        self.children = patient["children"]
        self.smoker = patient["smoker"]
        self.region = patient["region"]
        self.charges = patient["charges"]
        # There can be added info if needed, lets make sure to change the the parameters in the exceptions handler
    def __repr__(self):
       return """ Patients Info:
        AGE: {age}
        SEX: {sex}
        BMI: {bmi}
        Number of children: {children}
        Smoker: {smoker}
        Region: {region}
        Insurance Costs: {charges}""".format(age = self.age, sex = self.sex, bmi = self.bmi, children = self.children, smoker = self.smoker, region = self.region, charges = self.charges)
 
    #If we want to convert our class back to a dictionary , lets use this function
    def patient_to_dictionary(self):
        patient_dict ={}
        patient_dict["age"] = self.age
        patient_dict["sex"] = self.sex
        patient_dict["bmi"] = self.bmi
        patient_dict["children"] = self.children
        patient_dict["smoker"] = self.smoker
        patient_dict["region"] = self.region
        patient_dict["charges"] = self.charges
        return patient_dict
    
    # THis next methods return the data asked for from the Patient class
    def get_patient_age(self):
        return self.age
        
    def get_patient_sex(self):
        return self.sex
    
    def get_patient_bmi(self):
        return self.bmi
    
    def get_patient_children(self):
        return self.children
    
    def get_patient_smoker(self):
        return self.smoker
    
    def get_patient_region(self):
        return self.region
    
    def get_patient_charges(self):
        return self.charges

# %% [markdown]
# The class is ready to be used. Next step is making the list that has all the patiets info saved in dictionaries into a list of the class __Patient__.

# %%
patients_list_class = []
for patient in patients_list:
    patients_list_class.append(Patient(patient))
    
print(patients_list_class[0])
# Out:
#  Patients Info:
#         AGE: 19
#         SEX: female
#         BMI: 27.9
#         Number of children: 0
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 16884.924

# %% [markdown]
# Now that we have our list of Patients class, it can be used in different ways.
# First doing a list that contains all the insurances costs.

# %%
def patients_insurances_list(patients):
    patients_insurances_costs = []
    for patient in patients:
        patients_insurances_costs.append(patient.get_patient_charges())
    return patients_insurances_costs
    
print(patients_insurances_list(patients_list_class))
# Out:
# ['16884.924', '1725.5523', '4449.462', '21984.47061', '3866.8552', '3756.6216', '8240.5896', '7281.5056', '6406.4107', '28923.13692', '2721.3208', '27808.7251', '1826.843', '11090.7178', '39611.7577', '1837.237', '10797.3362', '2395.17155', '10602.385', '36837.467', '13228.84695', '4149.736', '1137.011', '37701.8768', '6203.90175', '14001.1338', '14451.83515', '12268.63225', '2775.19215', '38711', '35585.576', '2198.18985', '4687.797', '13770.0979', '51194.55914', '1625.43375', '15612.19335', '2302.3', '39774.2763', '48173.361', '3046.062', '4949.7587', '6272.4772', '6313.759', '6079.6715', '20630.28351', '3393.35635', '3556.9223', '12629.8967', '38709.176', '2211.13075', '3579.8287', '23568.272', '37742.5757', '8059.6791', '47496.49445', '13607.36875', '34303.1672', '23244.7902', '5989.52365', '8606.2174', '4504.6624', '30166.61817', '4133.64165', '14711.7438', '1743.214', '14235.072', '6389.37785', '5920.1041', '17663.1442', '16577.7795', '6799.458', '11741.726', '11946.6259', '7726.854', '11356.6609', '3947.4131', '1532.4697', '2755.02095', '6571.02435', '4441.21315', '7935.29115', '37165.1638', '11033.6617', '39836.519', '21098.55405', '43578.9394', '11073.176', '8026.6666', '11082.5772', '2026.9741', '10942.13205', '30184.9367', '5729.0053', '47291.055', '3766.8838', '12105.32', '10226.2842', '22412.6485', '15820.699', '6186.127', '3645.0894', '21344.8467', '30942.1918', '5003.853', '17560.37975', '2331.519', '3877.30425', '2867.1196', '47055.5321', '10825.2537', '11881.358', '4646.759', '2404.7338', '11488.31695', '30259.99556', '11381.3254', '19107.7796', '8601.3293', '6686.4313', '7740.337', '1705.6245', '2257.47525', '39556.4945', '10115.00885', '3385.39915', '17081.08', '9634.538', '32734.1863', '6082.405', '12815.44495', '13616.3586', '11163.568', '1632.56445', '2457.21115', '2155.6815', '1261.442', '2045.68525', '27322.73386', '2166.732', '27375.90478', '3490.5491', '18972.495', '18157.876', '20745.9891', '5138.2567', '40720.55105', '9877.6077', '10959.6947', '1842.519', '5125.2157', '7789.635', '6334.34355', '19964.7463', '7077.1894', '6948.7008', '21223.6758', '15518.18025', '36950.2567', '19749.38338', '21348.706', '36149.4835', '10450.552', '5152.134', '5028.1466', '10407.08585', '4830.63', '6128.79745', '2719.27975', '4827.90495', '13405.3903', '8116.68', '1694.7964', '5246.047', '2855.43755', '48824.45', '6455.86265', '10436.096', '8823.279', '8538.28845', '11735.87905', '1631.8212', '4005.4225', '7419.4779', '7731.4271', '43753.33705', '3981.9768', '5325.651', '6775.961', '4922.9159', '12557.6053', '4883.866', '2137.6536', '12044.342', '1137.4697', '1639.5631', '5649.715', '8516.829', '9644.2525', '14901.5167', '2130.6759', '8871.1517', '13012.20865', '37133.8982', '7147.105', '4337.7352', '11743.299', '20984.0936', '13880.949', '6610.1097', '1980.07', '8162.71625', '3537.703', '5002.7827', '8520.026', '7371.772', '10355.641', '2483.736', '3392.9768', '25081.76784', '5012.471', '10564.8845', '5253.524', '34779.615', '19515.5416', '11987.1682', '2689.4954', '24227.33724', '7358.17565', '9225.2564', '7443.64305', '14001.2867', '1727.785', '12333.828', '6710.1919', '19444.2658', '1615.7667', '4463.2051', '17352.6803', '7152.6714', '38511.6283', '5354.07465', '35160.13457', '7196.867', '29523.1656', '24476.47851', '12648.7034', '1986.9334', '1832.094', '4040.55825', '12829.4551', '47305.305', '44260.7499', '4260.744', '41097.16175', '13047.33235', '43921.1837', '5400.9805', '11520.09985', '33750.2918', '11837.16', '17085.2676', '24869.8368', '36219.40545', '20462.99766', '46151.1245', '17179.522', '14590.63205', '7441.053', '9282.4806', '1719.4363', '42856.838', '7265.7025', '9617.66245', '2523.1695', '9715.841', '2803.69785', '2150.469', '12928.7911', '9855.1314', '22331.5668', '48549.17835', '4237.12655', '11879.10405', '9625.92', '7742.1098', '9432.9253', '14256.1928', '47896.79135', '25992.82104', '3172.018', '20277.80751', '42112.2356', '2156.7518', '3906.127', '1704.5681', '16297.846', '21978.6769', '38746 ...

# %% [markdown]
# The funtion __patients_insurances_list__ returns a list that contains all the insurances costs from the patients. Now a new function that calculates the average insurances costs around all the patients.

# %%
def average_insurance_cost(insurances): # The funtion gets a list that cntains the insurance
    total_insurance = 0
    for insurance in insurances:
        total_insurance += float(insurance) # has the insurances are stored in strings we need o convert them to float number to make operations
    return total_insurance/len(insurances) # The function returns the average

# %% [markdown]
# Now lets test the functions.

# %%
insurances_costs = patients_insurances_list(patients_list_class)
average_insurance = average_insurance_cost(insurances_costs)
print(insurances_costs)
print("The average insurance cost is: {}".format(average_insurance))
# Out:
# ['16884.924', '1725.5523', '4449.462', '21984.47061', '3866.8552', '3756.6216', '8240.5896', '7281.5056', '6406.4107', '28923.13692', '2721.3208', '27808.7251', '1826.843', '11090.7178', '39611.7577', '1837.237', '10797.3362', '2395.17155', '10602.385', '36837.467', '13228.84695', '4149.736', '1137.011', '37701.8768', '6203.90175', '14001.1338', '14451.83515', '12268.63225', '2775.19215', '38711', '35585.576', '2198.18985', '4687.797', '13770.0979', '51194.55914', '1625.43375', '15612.19335', '2302.3', '39774.2763', '48173.361', '3046.062', '4949.7587', '6272.4772', '6313.759', '6079.6715', '20630.28351', '3393.35635', '3556.9223', '12629.8967', '38709.176', '2211.13075', '3579.8287', '23568.272', '37742.5757', '8059.6791', '47
# The average insurance cost is: 13270.422265141257

# %% [markdown]
# NExt step is doing the same that we did before for other data info, and create different functions to interact and separate the data in other lists to make it easy to work with. Going in order, starting with the age crating a list with this data and making a function to get the average age.

# %%
def get_all_patients_ages(patients): #Creating list containing th ages of the patients
    patients_ages_list = []
    for patient in patients:
        patients_ages_list.append(patient.age)
    return patients_ages_list

def average_age_for_patients(ages): # Calculate the average age 
    total_ages = 0.0
    for age in ages:
        total_ages += int(age)
    return total_ages/len(ages)

# %% [markdown]
# Testing our funtions we have:

# %%
patients_ages = get_all_patients_ages(patients_list_class)
average_age = average_age_for_patients(patients_ages)
print(patients_ages)
print("The average age for all patients is: {}".format(average_age))
# Out:
# ['19', '18', '28', '33', '32', '31', '46', '37', '37', '60', '25', '62', '23', '56', '27', '19', '52', '23', '56', '30', '60', '30', '18', '34', '37', '59', '63', '55', '23', '31', '22', '18', '19', '63', '28', '19', '62', '26', '35', '60', '24', '31', '41', '37', '38', '55', '18', '28', '60', '36', '18', '21', '48', '36', '40', '58', '58', '18', '53', '34', '43', '25', '64', '28', '20', '19', '61', '40', '40', '28', '27', '31', '53', '58', '44', '57', '29', '21', '22', '41', '31', '45', '22', '48', '37', '45', '57', '56', '46', '55', '21', '53', '59', '35', '64', '28', '54', '55', '56', '38', '41', '30', '18', '61', '34', '20', '19', '26', '29', '63', '54', '55', '37', '21', '52', '60', '58', '29', '49', '37', '44', '18', '20', '44', '47', '26', '19', '52', '32', '38', '59', '61', '53', '19', '20', '22', '19', '22', '54', '22', '34', '26', '34', '29', '30', '29', '46', '51', '53', '19', '35', '48', '32', '42', '40', '44', '48', '18', '30', '50', '42', '18', '54', '32', '37', '47', '20', '32', '19', '27', '63', '49', '18', '35', '24', '63', '38', '54', '46', '41', '58', '18', '22', '44', '44', '36', '26', '30', '41', '29', '61', '36', '25', '56', '18', '19', '39', '45', '51', '64', '19', '48', '60', '27', '46', '28', '59', '35', '63', '40', '20', '40', '24', '34', '45', '41', '53', '27', '26', '24', '34', '53', '32', '19', '42', '55', '28', '58', '41', '47', '42', '59', '19', '59', '39', '40', '18', '31', '19', '44', '23', '33', '55', '40', '63', '54', '60', '24', '19', '29', '18', '63', '54', '27', '50', '55', '56', '38', '51', '19', '58', '20', '52', '19', '53', '46', '40', '59', '45', '49', '18', '50', '41', '50', '25', '47', '19', '22', '59', '51', '40', '54', '30', '55', '52', '46', '46', '63', '59', '52', '28', '29', '25', '22', '25', '18', '19', '47', '31', '48', '36', '53', '56', '28', '57', '29', '28', '30', '58', '41', '50', '19', '43', '49', '27', '52', '50', '54', '44', '32', '34', '26', '34', '57', '29', '40', '27', '45', '64', '52', '61', '52', '61', '56', '43', '64', '60', '62', '50', '46', '24', '62', '60', '63', '49', '34', '33', '46', '36', '19', '57', '50', '30', '33', '18', '46', '46', '47', '23', '18', '48', '35', '19', '21', '21', '49', '56', '42', '44', '18', '61', '57', '42', '26', '20', '23', '39', '24', '64', '62', '27', '55', '55', '35', '44', '19', '58', '50', '26', '24', '48', '19', '48', '49', '46', '46', '43', '21', '64', '18', '51', '47', '64', '49', '31', '52', '33', '47', '38', '32', '19', '44', '26', '25', '19', '43', '52', '36', '64', '63', '64', '61', '40', '25', '48', '45', '38', '18', '21', '27', '19', '29', '42', '60', '31', '60', '22', '35', '52', '26', '31', '33', '18', '59', '56', '45', '60', '56', '40', '35', '39', '30', '24', '20', '32', '59', '55', '57', '56', '40', '49', '42', '62', '56', '19', '30', '60', '56', '28', '18', '27', '18', '19', '47', '54', '61', '24', '25', '21', '23', '63', '49', '18', '51', '48', '31', '54', '19', '44', '53', '19', '61', '18', '61', '21', '20', '31', '45', '44', '62', '29', '43', '51', '19', '38', '37', '22', '21', '24', '57', '56', '27', '51', '19', '39', '58', '20', '45', '35', '31', '50', '32', '51', '38', '42', '18', '19', '51', '46', '18', '57', '62', '59', '37', '64', '38', '33', '46', '46', '53', '34', '20', '63', '54', '54', '49', '28', '54', '25', '43', '63', '32', '62', '52', '25', '28', '46', '34', '35', '19', '46', '54', '27', '50', '18', '19', '38', '41', '49', '48', '31', '18', '30', '62', '57', '58', '22', '31', '52', '25', '59', '19', '39', '32', '19', '33', '21', '34', '61', '38', '58', '47', '20', '21', '41', '46', '42', '34', '43', '52', '18', '51', '56', '64', '19', '51', '27', '59', '28', '30', '47', '38', '18', '34', '20', '47', '56', '49', '19', '55', '30', '37', '49', '18', '59', '29', '36', '33', '58', '44', '53', '24', '29', '40', '51', '64', '19', '35', '39', '56', '33', '42', '61', '23', '43', '48', '39', '40', '18', '58', '49', '53', '48', '45', '59', '52', '26', '27', '48', '57', '37', '57', '32', '18', '64', '43', '49 ...
# The average age for all patients is: 39.20702541106129

# %% [markdown]
# There is our age list and thhe average around all of them.
#
# Now we want to split our patients by other data and do certain things with this data like this:
# -Split them by their sex and see how many males and females there are
#
# -Split them by if they have a normal bmi or they have a bmi under the healthy bmi status or over another bmi status that says they suffer from obesity and claculate the average bmi
#
# -Split them by how many children the have and see how many of them doesnt have chldren or have around 1 aand 4 children or if they have more.
#
# -Split them if they smoke or not
#
# -And split them by their region

# %%
# sex data funtions
def split_patients_by_sex(patients): # Returns a dictionary spliting the patients by their sex
    patients_by_sex = {}
    for patient in patients:
        if patient.sex in patients_by_sex:
            patients_by_sex[patient.sex].append(patient)
        else:
            patients_by_sex[patient.sex] = [patient]
    return patients_by_sex

def how_many_males_and_females(patients_sex):
    males = len(patients_sex["male"])
    females= len(patients_sex["female"])
    return males, females

# bmi data funtions
def split_patients_by_bmi(patients): # split the patients depending if their bmi is under, over or between certainn value of bmi
    underweight = 18.50
    normal_weight = 24.90
    overweight = 29.90
    patients_bmi_dict ={"Underweight": [], "Normal weight": [], "Overweight": [], "Obesity": []}
    
    for patient in patients:
        bmi = float(patient.bmi)
        if bmi < underweight:
            patients_bmi_dict["Underweight"].append(patient)
        elif bmi >= underweight and bmi <= normal_weight:
            patients_bmi_dict["Normal weight"].append(patient)
        elif bmi > normal_weight and bmi <= overweight:
            patients_bmi_dict["Overweight"].append(patient)
        elif bmi > overweight:
            patients_bmi_dict["Obesity"].append(patient)
    return patients_bmi_dict

def num_of_patients_bmi(patients_bmi): # returns the number of patints in each category of bmi we already defined
    num_underweight = len(patients_bmi["Underweight"])
    num_normal_weight = len(patients_bmi["Normal weight"])
    num_overweight = len(patients_bmi["Overweight"])
    num_obesity = len(patients_bmi["Obesity"])
    return num_underweight, num_normal_weight, num_overweight, num_obesity

def average_bmi(patients):
    total_bmi = 0
    for patient in patients:
        total_bmi += float(patient.bmi)
    return total_bmi/len(patients)

# children data funtions
def patients_by_num_children(patients):
    patients_children_dict = {}
    for patient in patients:
        num_children = int(patient.children)
        if num_children in patients_children_dict:
            patients_children_dict[num_children].append(patient)
        else:
            patients_children_dict[num_children] = [patient]
    return patients_children_dict

# smoker data functions
def split_patients_by_smoking(patients):
    patients_smoking_dict = {"Smoker": [], "Non-smoker": []}
    for patient in patients:
        if patient.smoker == "yes":
            patients_smoking_dict["Smoker"].append(patient)
        else:
            patients_smoking_dict["Non-smoker"].append(patient)
    return patients_smoking_dict

def how_many_patients_smoke(patients_smoking):
    smoker = len(patients_smoking["Smoker"])
    return smoker
def how_many_patients_no_smoke(patients_smoking):
    non_smoker = len(patients_smoking["Non-smoker"])
    return non_smoker
# region data funtions
def split_patients_by_region(patients):
    patients_region_dict = {}
    for patient in patients:
        if patient.region in patients_region_dict:
            patients_region_dict[patient.region].append(patient)
        else:
            patients_region_dict[patient.region] = [patient]
    return patients_region_dict

# %% [markdown]
# And here is the test for our functions

# %%
#for sex data
patients_by_sex = split_patients_by_sex(patients_list_class)
num_males, num_females = how_many_males_and_females(patients_by_sex)
#print(patients_by_sex)

#for bmi data
patients_by_bmi = split_patients_by_bmi(patients_list_class)
underweight_pat, normal_weight_pat, overweight_pat, obese_pat = num_of_patients_bmi(patients_by_bmi)
#print("{} {} {} {} ".format(underweight_pat, normal_weight_pat, overweight_pat, obese_pat))
#print(patients_by_bmi)

#for children data
patients_by_children = patients_by_num_children(patients_list_class)
#print(patients_by_children.keys())
#for num_child in patients_by_children.keys():
#    print(len(patients_by_children[num_child]))

#for smoker data
patients_by_smoking_status = split_patients_by_smoking(patients_list_class)
#print(patients_by_smoking_status)
#num_smokers, num_non_smokers = how_many_patients_smoke(patients_by_smoking_status)
#print(num_non_smokers)

#for region data
patients_regions = split_patients_by_region(patients_list_class)
print(patients_regions)
#for region in patients_regions:
    #print(len(patients_regions[region]))
# Out:
# {'southwest': [ Patients Info:
#         AGE: 19
#         SEX: female
#         BMI: 27.9
#         Number of children: 0
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 16884.924,  Patients Info:
#         AGE: 23
#         SEX: male
#         BMI: 34.4
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 1826.843,  Patients Info:
#         AGE: 19
#         SEX: male
#         BMI: 24.6
#         Number of children: 1
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 1837.237,  Patients Info:
#         AGE: 56
#         SEX: male
#         BMI: 40.3
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs:
#         Number of children: 3
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 7418.522,  Patients Info:
#         AGE: 24
#         SEX: male
#         BMI: 32.7
#         Number of children: 0
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 34472.841,  Patients Info:
#         AGE: 24
#         SEX: male
#         BMI: 25.8
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 1972.95,  Patients Info:
#         AGE: 48
#         SEX: male
#         BMI: 29.6
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 21232.18226,  Patients Info:
#         AGE: 48
#         SEX: female
#         BMI: 22.8
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 8269.044,  Patients Info:
#         AGE: 38
#         SEX: female
#         BMI: 27.6
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 5383.536,  Patients Info:
#         AGE: 26
#         SEX: female
#         BMI: 34.2
#         Number of children: 2
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 3987.926,  Patients Info:
#         AGE: 51
#         SEX: male
#         BMI: 37
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 8798.593,  Patients Info:
#         AGE: 21
#         SEX: female
#         BMI: 34.6
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 2020.177,  Patients Info:
#         AGE: 54
#         SEX: male
#         BMI: 31.6
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 9850.432,  Patients Info:
#         AGE: 54
#         SEX: female
#         BMI: 23
#         Number of children: 3
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 12094.478,  Patients Info:
#         AGE: 28
#         SEX: female
#         BMI: 25.8
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 3161.454,  Patients Info:
#         AGE: 49
#         SEX: male
#         BMI: 30.9
#         Number of children: 0
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 39727.614,  Patients Info:
#         AGE: 47
#         SEX: male
#         BMI: 29.8
#         Number of children: 3
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 25309.489,  Patients Info:
#         AGE: 48
#         SEX: female
#         BMI: 28.9
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 8277.523,  Patients Info:
#         AGE: 29
#         SEX: female
#         BMI: 25.6
#         Number of children: 4
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 5708.867,  Patients Info:
#         AGE: 42
#         SEX: female
#         BMI: 25.3
#         Number of children: 1
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 7045.499,  Patients Info:
#         AGE: 47
#         SEX: female
#         BMI: 32
#         Number of children: 1
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 8551.347,  Patients Info:
#         AGE: 32
#         SEX: male
#         BMI: 31.5
#         Number of children: 1
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 4076.497,  Patients Info:
#         AGE: 39
#         SEX: female
#         BMI: 18.3
#         Number of children: 5
#         Smoker: yes
#         Region: southwest
#         Insurance Costs: 19023.26,  Patients Info:
#         AGE: 56
#         SEX: male
#         BMI: 22.1
#         Number of children: 0
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 10577.087,  Patients Info:
#         AGE: 23
#         SEX: male
#         BMI: 32.7
#         Number of children: 3
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 3591.48,  Patients Info:
#         AGE: 50
#         SEX: female
#         BMI: 33.7
#         Number of children: 4
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 11299.343,  Patients Info:
#         AGE: 53
#         SEX: male
#         BMI: 28.6
#         Number of children: 3
#         Smoker: no
#         Region: southwest
#         Insurance Costs: 11253.421,  Patients Info:
#         AGE: 37
#         SEX: male
#         BMI: 29.8
# ...
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 16138.76205,  Patients Info:
#         AGE: 45
#         SEX: female
#         BMI: 39.995
#         Number of children: 3
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9704.66805,  Patients Info:
#         AGE: 54
#         SEX: male
#         BMI: 25.46
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 25517.11363,  Patients Info:
#         AGE: 34
#         SEX: male
#         BMI: 21.375
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4500.33925,  Patients Info:
#         AGE: 27
#         SEX: female
#         BMI: 30.59
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 16796.41194,  Patients Info:
#         AGE: 20
#         SEX: male
#         BMI: 30.115
#         Number of children: 5
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4915.05985,  Patients Info:
#         AGE: 34
#         SEX: male
#         BMI: 34.675
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4518.82625,  Patients Info:
#         AGE: 24
#         SEX: female
#         BMI: 20.52
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 14571.8908,  Patients Info:
#         AGE: 38
#         SEX: female
#         BMI: 27.835
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7144.86265,  Patients Info:
#         AGE: 39
#         SEX: female
#         BMI: 23.275
#         Number of children: 3
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7986.47525,  Patients Info:
#         AGE: 33
#         SEX: female
#         BMI: 36.29
#         Number of children: 3
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 6551.7501,  Patients Info:
#         AGE: 47
#         SEX: male
#         BMI: 19.19
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 8627.5411,  Patients Info:
#         AGE: 28
#         SEX: male
#         BMI: 29.26
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4438.2634,  Patients Info:
#         AGE: 25
#         SEX: male
#         BMI: 24.985
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 23241.47453,  Patients Info:
#         AGE: 51
#         SEX: male
#         BMI: 27.74
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9957.7216,  Patients Info:
#         AGE: 37
#         SEX: female
#         BMI: 17.29
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 6877.9801,  Patients Info:
#         AGE: 30
#         SEX: female
#         BMI: 27.93
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4137.5227,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 21.565
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 13747.87235,  Patients Info:
#         AGE: 22
#         SEX: male
#         BMI: 28.88
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2250.8352,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 23.085
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 1704.70015,  Patients Info:
#         AGE: 20
#         SEX: male
#         BMI: 30.685
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 33475.81715,  Patients Info:
#         AGE: 55
#         SEX: male
#         BMI: 35.245
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11394.06555,  Patients Info:
#         AGE: 43
#         SEX: female
#         BMI: 25.08
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7325.0482,  Patients Info:
#         AGE: 64
#         SEX: male
#         BMI: 26.41
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 14394.5579,  Patients Info:
#         AGE: 49
#         SEX: male
#         BMI: 29.83
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9288.0267,  Patients Info:
#         AGE: 39
#         SEX: male
#         BMI: 42.655
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 5757.41345,  Patients Info:
#         AGE: 63
#         SEX: male
#         BMI: 31.445
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 13974.45555,  Patients Info:
#         AGE: 54
#         SEX: female
#         BMI: 28.88
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 12096.6512,  Patients Info:
#         AGE: 60
#         SEX: female
#         BMI: 18.335
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 13204.28565,  Patients Info:
#         AGE: 21
#         SEX: male
#         BMI: 26.03
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2102.2647,  Patients Info:
#         AGE: 55
#         SEX: male
#         BMI: 28.975
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 10796.35025,  Patients Info:
#         AGE: 55
#         SEX: female
#         BMI: 29.83
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11286.5387,  Patients Info:
#         AGE: 18
#         SEX: female
#         BMI: 31.35
#         Number of children: 4
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4561.1885,  Patients Info:
#         AGE: 51
#         SEX: female
#         BMI: 34.96
#         Number of children: 2
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 44641.1974,  Patients Info:
#         AGE: 52
#         SEX: female
#         BMI: 30.875
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 23045.56616,  Patients Info:
#         AGE: 33
#         SEX: female
#         BMI: 19.095
#         Number of children: 2
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 16776.30405,  Patients Info:
#         AGE: 54
#         SEX: female
#         BMI: 32.3
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11512.405,  Patients Info:
#         AGE: 23
#         SEX: male
#         BMI: 24.51
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2396.0959,  Patients Info:
#         AGE: 41
#         SEX: male
#         BMI: 29.64
#         Number of children: 5
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9222.4026,  Patients Info:
#         AGE: 27
#         SEX: female
#         BMI: 32.395
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 18903.49141,  Patients Info:
#         AGE: 23
#         SEX: female
#         BMI: 42.75
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 40904.1995,  Patients Info:
#         AGE: 57
#         SEX: male
#         BMI: 40.28
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 20709.02034,  Patients Info:
#         AGE: 18
#         SEX: female
#         BMI: 30.305
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2203.73595,  Patients Info:
#         AGE: 36
#         SEX: female
#         BMI: 22.135
#         Number of children: 3
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7228.21565,  Patients Info:
#         AGE: 20
#         SEX: female
#         BMI: 30.59
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2459.7201,  Patients Info:
#         AGE: 18
#         SEX: female
#         BMI: 28.215
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2200.83085,  Patients Info:
#         AGE: 35
#         SEX: female
#         BMI: 26.125
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 5227.98875,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 27.36
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 17178.6824,  Patients Info:
#         AGE: 23
#         SEX: female
#         BMI: 34.865
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2899.48935,  Patients Info:
#         AGE: 42
#         SEX: female
#         BMI: 41.325
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7650.77375,  Patients Info:
#         AGE: 48
#         SEX: female
#         BMI: 27.36
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9447.3824,  Patients Info:
#         AGE: 45
#         SEX: male
#         BMI: 23.56
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 8603.8234,  Patients Info:
#         AGE: 43
#         SEX: female
#         BMI: 25.27
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 21771.3423,  Patients Info:
#         AGE: 41
#         SEX: female
#         BMI: 21.755
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 13725.47184,  Patients Info:
#         AGE: 58
#         SEX: female
#         BMI: 32.395
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 13019.16105,  Patients Info:
#         AGE: 51
#         SEX: male
#         BMI: 32.3
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 9964.06,  Patients Info:
#         AGE: 37
#         SEX: female
#         BMI: 25.555
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 20296.86345,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 21.47
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 1702.4553,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 39.14
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 12890.05765,  Patients Info:
#         AGE: 30
#         SEX: female
#         BMI: 21.945
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4718.20355,  Patients Info:
#         AGE: 41
#         SEX: male
#         BMI: 23.94
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 6858.4796,  Patients Info:
#         AGE: 38
#         SEX: male
#         BMI: 16.815
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 6640.54485,  Patients Info:
#         AGE: 58
#         SEX: male
#         BMI: 30.305
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11938.25595,  Patients Info:
#         AGE: 63
#         SEX: female
#         BMI: 21.66
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 14449.8544,  Patients Info:
#         AGE: 37
#         SEX: male
#         BMI: 22.705
#         Number of children: 3
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 6985.50695,  Patients Info:
#         AGE: 32
#         SEX: male
#         BMI: 33.63
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 37607.5277,  Patients Info:
#         AGE: 24
#         SEX: male
#         BMI: 29.83
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 18648.4217,  Patients Info:
#         AGE: 52
#         SEX: female
#         BMI: 23.18
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 10197.7722,  Patients Info:
#         AGE: 32
#         SEX: female
#         BMI: 20.52
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 4544.2348,  Patients Info:
#         AGE: 49
#         SEX: female
#         BMI: 33.345
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 10370.91255,  Patients Info:
#         AGE: 24
#         SEX: male
#         BMI: 31.065
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 34254.05335,  Patients Info:
#         AGE: 22
#         SEX: female
#         BMI: 30.4
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2741.948,  Patients Info:
#         AGE: 39
#         SEX: male
#         BMI: 29.925
#         Number of children: 1
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 22462.04375,  Patients Info:
#         AGE: 18
#         SEX: female
#         BMI: 21.66
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 14283.4594,  Patients Info:
#         AGE: 47
#         SEX: female
#         BMI: 24.32
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 8534.6718,  Patients Info:
#         AGE: 28
#         SEX: female
#         BMI: 17.29
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 3732.6251,  Patients Info:
#         AGE: 38
#         SEX: female
#         BMI: 19.95
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7133.9025,  Patients Info:
#         AGE: 58
#         SEX: male
#         BMI: 25.175
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11931.12525,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 26.125
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 1708.92575,  Patients Info:
#         AGE: 42
#         SEX: male
#         BMI: 24.605
#         Number of children: 2
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 21259.37795,  Patients Info:
#         AGE: 29
#         SEX: female
#         BMI: 21.85
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 16115.3045,  Patients Info:
#         AGE: 18
#         SEX: male
#         BMI: 28.31
#         Number of children: 1
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 11272.33139,  Patients Info:
#         AGE: 35
#         SEX: male
#         BMI: 39.71
#         Number of children: 4
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 19496.71917,  Patients Info:
#         AGE: 62
#         SEX: male
#         BMI: 26.695
#         Number of children: 0
#         Smoker: yes
#         Region: northeast
#         Insurance Costs: 28101.33305,  Patients Info:
#         AGE: 61
#         SEX: male
#         BMI: 33.535
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 13143.33665,  Patients Info:
#         AGE: 42
#         SEX: female
#         BMI: 32.87
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 7050.0213,  Patients Info:
#         AGE: 23
#         SEX: female
#         BMI: 24.225
#         Number of children: 2
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 22395.74424,  Patients Info:
#         AGE: 18
#         SEX: female
#         BMI: 31.92
#         Number of children: 0
#         Smoker: no
#         Region: northeast
#         Insurance Costs: 2205.9808]}

# %% [markdown]
# Now that all this funtions were tested and have all our data separate in different dictionaries and lists, we can start study the info we have by managing it in a easier way.
#
# We already have an average insurance costs for all patients, but not an average for each region. Next step is calculating an average for region and see if this means vary from the global average.

# %%
def average_insurance_cost_by_region(patients):
    global_average = average_insurance_cost(patients_insurances_list(patients))
    print("The average insurance cost is: {}. \n".format(global_average))
    patients_by_region_list = split_patients_by_region(patients)
    for region in patients_by_region_list:
        #print(patients_regions[region])
        insurances_list_region = patients_insurances_list(patients_by_region_list[region])
        #print(insurances_list)
        average_region_insurance = average_insurance_cost(insurances_list_region)
        average_dif = average_region_insurance -average_insurance 
        print("For the {} region  the average insurance cost is: {} with a difference of {} with the global average insurance cost.\n".format(region.upper(), average_region_insurance, average_dif))
        
        
average_insurance_cost_by_region(patients_list_class)
# Out:
# The average insurance cost is: 13270.422265141257.
#
# For the SOUTHWEST region  the average insurance cost is: 12346.93737729231 with a difference of -923.4848878489465 with the global average insurance cost.
#
# For the SOUTHEAST region  the average insurance cost is: 14735.411437609895 with a difference of 1464.9891724686386 with the global average insurance cost.
#
# For the NORTHWEST region  the average insurance cost is: 12417.575373969228 with a difference of -852.8468911720283 with the global average insurance cost.
#
# For the NORTHEAST region  the average insurance cost is: 13406.3845163858 with a difference of 135.96225124454395 with the global average insurance cost.

# %% [markdown]
# From he results obtained, the average cost by region has a significant difference in three regions. So the region can affect the insurance total for their patients?.
#
# It may not be posiible, if we think of this data may be from the same insurance company then the total price must not be affected by their region but by other factors (and as we are talking about an insurance it must be about the health of the a
# patient). So lets see how much the insurance varies by other data like sex or being a smoker.
#
# But firt lets count the poeple, lets count it in different ways so we can now if there is an even number for certain data and study it. This is going to be a big function but we already have acouple of funtions that can help us.

# %%
def counting_patients(patients):
    # first we count the males and females in the data given
    patients_sex_dict = split_patients_by_sex(patients)
    males, females = how_many_males_and_females(patients_sex_dict)
    print("There are {} males and {} females on the data given.\n".format(males,females))
    
    #next we count people by their bmi condition
    patients_bmi_dict = split_patients_by_bmi(patients)
    underweight_patients, normal_weight_patients, overweight_patients, obese_patients = num_of_patients_bmi(patients_bmi_dict)
    print(""" 
    There are {} patients with an underweight condition.
    There are {} patients with a normal weight.
    There are {} patients with an underweight condition.
    There are {} patients with an obesity condition.\n""".format(underweight_patients, normal_weight_patients, overweight_patients, obese_patients))
    
    # counting people by the number of children they have
    patients_children_dict = patients_by_num_children(patients)
    for children in patients_children_dict.keys():
        if children == 0:
            print("There are {} patients with no child".format(len(patients_children_dict[children])))
        elif children == 1:
            print("There is {} patients with a child".format(len(patients_children_dict[children])))
        else:
            print("There is {} patients with {} children".format(len(patients_children_dict[children]), children))
    
    # counting people by their smoker status
    patients_smoking_dict = split_patients_by_smoking(patients)
    num_smokers = how_many_patients_smoke(patients_smoking_dict)
    num_non_smokers = how_many_patients_no_smoke(patients_smoking_dict)
    print("\nThere are {} patients that smoke and {} patients dont smoke.\n".format(num_smokers, num_non_smokers))
    
    #counting people by their region
    patients_region_dict = split_patients_by_region(patients)
    for region in patients_region_dict:
        print("There are {} patients in the {} region.".format(len(patients_region_dict[region]), region.upper()))
        
    #counting males and females by their bmi condition
    for cond in patients_bmi_dict:
        condition_by_sex_dict = split_patients_by_sex(patients_bmi_dict[cond])
        male_with_cond, female_with_condi = how_many_males_and_females(condition_by_sex_dict)
        print("There are {} males and {} females with {} condition.".format(male_with_cond, female_with_condi, cond))
    
    # counting males and females by their num of children
    for children in patients_children_dict:
        children_by_sex_dict = split_patients_by_sex(patients_children_dict[children])
        male_child, female_child = how_many_males_and_females(children_by_sex_dict)
        if children == 0:
            print("\nThere are {} males and {} females with no child.".format(male_child, female_child))
        elif children == 1:
            print("There are {} males and {} females with one child.".format(male_child, female_child))
        else:
            print("There are {} males and {} females with {} children.".format(male_child, female_child, children))
            
    # counting males and females by their smoke condition
    for dict in patients_smoking_dict:
        sex_by_smoke_cond = split_patients_by_sex(patients_smoking_dict[dict])
        smoking_male, smoking_female = how_many_males_and_females(sex_by_smoke_cond)
        if dict == "Smoker":
            print("\nThere are {} males and {} females that smoke.".format(smoking_male, smoking_female))
        else:
            print("There are {} males and {} females that dont smoke.\n".format(smoking_male, smoking_female))
            
    #counting male and females by region
    for region in patients_region_dict:
        region_by_sex_dict = split_patients_by_sex(patients_region_dict[region])
        region_males, region_females = how_many_males_and_females(region_by_sex_dict)
        print("There are {} males and {} females in the {} region".format(region_males, region_females, region.upper()))
    
    
counting_patients(patients_list_class)
# Out:
# There are 676 males and 662 females on the data given.
#
#
#     There are 20 patients with an underweight condition.
#     There are 222 patients with a normal weight.
#     There are 380 patients with an underweight condition.
#     There are 716 patients with an obesity condition.
#
# There are 574 patients with no child
# There is 324 patients with a child
# There is 157 patients with 3 children
# There is 240 patients with 2 children
# There is 18 patients with 5 children
# There is 25 patients with 4 children
#
# There are 274 patients that smoke and 1064 patients dont smoke.
#
# There are 325 patients in the SOUTHWEST region.
# There are 364 patients in the SOUTHEAST region.
# There are 325 patients in the NORTHWEST region.
# There are 324 patients in the NORTHEAST region.
# There are 8 males and 12 females with Underweight condition.
# There are 106 males and 116 females with Normal weight condition.
# There are 188 males and 192 females with Overweight condition.
# There are 374 males and 342 females with Obesity condition.
#
# There are 285 males and 289 females with no child.
# There are 166 males and 158 females with one child.
# There are 80 males and 77 females with 3 children.
# There are 121 males and 119 females with 2 children.
# There are 10 males and 8 females with 5 children.
# There are 14 males and 11 females with 4 children.
#
# There are 159 males and 115 females that smoke.
# There are 517 males and 547 females that dont smoke.
#
# There are 163 males and 162 females in the SOUTHWEST region
# There are 189 males and 175 females in the SOUTHEAST region
# There are 161 males and 164 females in the NORTHWEST region
# There are 163 males and 161 females in the NORTHEAST region

# %% [markdown]
# How much the insurance change by the smoker condition? We can approximate to this by getting an average for smokers and no-smokers and see the difference between them. First seeing if the number of people smoking is near to the people no smking.

# %%
def average_insurance_smoker_condition(patients):
    smoker_condi_dict = split_patients_by_smoking(patients)
    for lst in smoker_condi_dict:
        pass

# %%
max_child = 0
for patient in patients_list_class:
    if int(patient.children) > max_child:
        max_child = int(patient.children)
print(max_child)
# Out:
# 5
